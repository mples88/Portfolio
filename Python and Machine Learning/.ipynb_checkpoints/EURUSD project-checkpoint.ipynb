# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import nasdaqdatalink

# %%
raw_df = yf.download("EURUSD=X", start="2020-01-01", end="2024-07-01", period="1D")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_df
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2020-01-01  1.122083  1.122838  1.115947  1.122083   1.122083       0
# 2020-01-02  1.121894  1.122712  1.116682  1.122083   1.122083       0
# 2020-01-03  1.117081  1.118068  1.112570  1.117144   1.117144       0
# 2020-01-06  1.116246  1.120825  1.115810  1.116196   1.116196       0
# 2020-01-07  1.119583  1.119946  1.113487  1.119799   1.119799       0
# ...              ...       ...       ...       ...        ...     ...
# 2024-06-24  1.068776  1.074703  1.068444  1.068776   1.068776       0
# 2024-06-25  1.073272  1.074576  1.069221  1.073272   1.073272       0
# 2024-06-26  1.070962  1.072041  1.066769  1.070962   1.070962       0
# 2024-06-27  1.068011  1.072616  1.067783  1.068011   1.068011       0
# 2024-06-28  1.070847  1.072099  1.068604  1.070847   1.070847       0
#
# [1173 rows x 6 columns]

# %%
df = raw_df.loc[:,["Adj Close"]]

# %%
df
# Out:
#             Adj Close
# Date
# 2020-01-01   1.122083
# 2020-01-02   1.122083
# 2020-01-03   1.117144
# 2020-01-06   1.116196
# 2020-01-07   1.119799
# ...               ...
# 2024-06-24   1.068776
# 2024-06-25   1.073272
# 2024-06-26   1.070962
# 2024-06-27   1.068011
# 2024-06-28   1.070847
#
# [1173 rows x 1 columns]

# %% [markdown]
# ### calculation of the simple and log returns

# %%
# Daily percent change of the price

# %%
df["simple_rtn"] = df["Adj Close"].pct_change()

# %%
# The ratio indicates how much the price has changed from one day to the next.

# %%
df["log_rtn"] = np.log(df["Adj Close"] / df["Adj Close"].shift(1))

# %%
df
# Out:
#             Adj Close  simple_rtn   log_rtn
# Date
# 2020-01-01   1.122083         NaN       NaN
# 2020-01-02   1.122083    0.000000  0.000000
# 2020-01-03   1.117144   -0.004401 -0.004411
# 2020-01-06   1.116196   -0.000848 -0.000849
# 2020-01-07   1.119799    0.003228  0.003223
# ...               ...         ...       ...
# 2024-06-24   1.068776   -0.001742 -0.001744
# 2024-06-25   1.073272    0.004207  0.004198
# 2024-06-26   1.070962   -0.002153 -0.002155
# 2024-06-27   1.068011   -0.002755 -0.002759
# 2024-06-28   1.070847    0.002656  0.002652
#
# [1173 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Adj Close     0
# simple_rtn    1
# log_rtn       1
# dtype: int64

# %%
df["Adj Close"].plot();

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10), sharex=True)
df["Adj Close"].plot(ax=ax[0], kind = "line", title = "EUR/USD 2020-2024 daily - Adjusted Close");
df["simple_rtn"].plot(ax=ax[1], kind = "line", title = "EUR/USD 2020-2024 daily - Simple Returns");

# %%
import cufflinks as cf
import plotly.offline as iplot

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
qf = cf.QuantFig(raw_df, title="EUR/USD 2020-2024 daily", legend="top", name="EUR/USD price", kind='candlestick')
qf.add_volume()
qf.add_sma(periods=20, column="Close", color="red")
qf.add_ema(periods=20, color="green")

# %%
qf.iplot()
# Out:
# <div>                            <div id="ba2e04a4-537e-432a-adc6-0938a9ab82b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ba2e04a4-537e-432a-adc6-0938a9ab82b0")) {                    Plotly.newPlot(                        "ba2e04a4-537e-432a-adc6-0938a9ab82b0",                        [{"marker":{"color":["#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#80808 ...

# %%
# 21 day rolling mean and std dev

# %%
df_rolling = df[["simple_rtn"]].rolling(window=21)\
                                .agg(["mean", "std"])
df_rolling.columns = df_rolling.columns.droplevel()

# %%
df_rolling.head(30)
# Out:
#                 mean       std
# Date
# 2020-01-01       NaN       NaN
# 2020-01-02       NaN       NaN
# 2020-01-03       NaN       NaN
# 2020-01-06       NaN       NaN
# 2020-01-07       NaN       NaN
# 2020-01-08       NaN       NaN
# 2020-01-09       NaN       NaN
# 2020-01-10       NaN       NaN
# 2020-01-13       NaN       NaN
# 2020-01-14       NaN       NaN
# 2020-01-15       NaN       NaN
# 2020-01-16       NaN       NaN
# 2020-01-17       NaN       NaN
# 2020-01-20       NaN       NaN
# 2020-01-21       NaN       NaN
# 2020-01-22       NaN       NaN
# 2020-01-23       NaN       NaN
# 2020-01-24       NaN       NaN
# 2020-01-27       NaN       NaN
# 2020-01-28       NaN       NaN
# 2020-01-29       NaN       NaN
# 2020-01-30 -0.000871  0.002154
# 2020-01-31 -0.000818  0.002190
# 2020-02-03 -0.000346  0.002432
# 2020-02-04 -0.000421  0.002473
# 2020-02-05 -0.000642  0.002334
# 2020-02-06 -0.000652  0.002348
# 2020-02-07 -0.000559  0.002257
# 2020-02-10 -0.000696  0.002320
# 2020-02-11 -0.000875  0.002368

# %%
df = df.join(df_rolling)

# %%
df
# Out:
#             Adj Close  simple_rtn   log_rtn      mean       std
# Date
# 2020-01-01   1.122083         NaN       NaN       NaN       NaN
# 2020-01-02   1.122083    0.000000  0.000000       NaN       NaN
# 2020-01-03   1.117144   -0.004401 -0.004411       NaN       NaN
# 2020-01-06   1.116196   -0.000848 -0.000849       NaN       NaN
# 2020-01-07   1.119799    0.003228  0.003223       NaN       NaN
# ...               ...         ...       ...       ...       ...
# 2024-06-24   1.068776   -0.001742 -0.001744 -0.000545  0.004082
# 2024-06-25   1.073272    0.004207  0.004198 -0.000499  0.004132
# 2024-06-26   1.070962   -0.002153 -0.002155 -0.000664  0.004125
# 2024-06-27   1.068011   -0.002755 -0.002759 -0.000751  0.004150
# 2024-06-28   1.070847    0.002656  0.002652 -0.000405  0.004115
#
# [1173 rows x 5 columns]

# %%
# upper and lower tresholds

# %%
n_sigmas = 3
df["upper"] = df["mean"] + n_sigmas * df["std"]
df["lower"] = df["mean"] - n_sigmas * df["std"]

# %%
# outlier identification

# %%
df["outlier"] = (
    (df["simple_rtn"] > df["upper"]) | (df["simple_rtn"] < df["lower"])

)

# %%
df["outlier"].unique()
# Out:
# array([False,  True])

# %%
fig, ax = plt.subplots(figsize=(15, 10))

df[["simple_rtn", "upper", "lower"]].plot(ax=ax)
ax.scatter(df.loc[df["outlier"]].index,
           df.loc[df["outlier"], "simple_rtn"],
           color="black", label="outlier")
ax.set_title("EUR/USD returns including outlier based on tresholds bands")
ax.legend();

# %%
df[df["outlier"]==True]
# Out:
#             Adj Close  simple_rtn   log_rtn      mean       std     upper  \
# Date
# 2020-03-20   1.065735   -0.027752 -0.028144 -0.000639  0.008993  0.026340
# 2021-11-01   1.155668   -0.010863 -0.010923 -0.000067  0.003578  0.010668
# 2022-03-07   1.087453   -0.017378 -0.017530 -0.002382  0.004877  0.012248
#
#                lower  outlier
# Date
# 2020-03-20 -0.027617     True
# 2021-11-01 -0.010802     True
# 2022-03-07 -0.017012     True
