# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import nasdaqdatalink

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from statsmodels.tsa.stattools import acovf,acf,pacf,pacf_yw,pacf_ols
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

import warnings
warnings.filterwarnings("ignore")

# %%
raw_df = yf.download("AMZN", start="2014-01-01", end="2024-07-01", period="1D")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
raw_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02   19.940001   19.968000   19.701000   19.898500   19.898500
# 2014-01-03   19.914499   20.135500   19.811001   19.822001   19.822001
# 2014-01-06   19.792500   19.850000   19.421000   19.681499   19.681499
# 2014-01-07   19.752001   19.923500   19.714500   19.901501   19.901501
# 2014-01-08   19.923500   20.150000   19.802000   20.096001   20.096001
# ...                ...         ...         ...         ...         ...
# 2024-06-24  189.330002  191.000000  185.330002  185.570007  185.570007
# 2024-06-25  186.809998  188.839996  185.419998  186.339996  186.339996
# 2024-06-26  186.919998  194.800003  186.259995  193.610001  193.610001
# 2024-06-27  195.009995  199.839996  194.199997  197.850006  197.850006
# 2024-06-28  197.729996  198.850006  192.500000  193.250000  193.250000
#
#               Volume
# Date
# 2014-01-02  42756000
# 2014-01-03  44204000
# 2014-01-06  63412000
# 2014-01-07  38320000
# 2014-01-08  46330000
# ...              ...
# 2024-06-24  50610400
# 2024-06-25  45898500
# 2024-06-26  65103900
# 2024-06-27  74397500
# 2024-06-28  76930200
#
# [2640 rows x 6 columns]

# %%
df = raw_df.loc[:,["Adj Close"]]

# %%
df
# Out:
#              Adj Close
# Date
# 2014-01-02   19.898500
# 2014-01-03   19.822001
# 2014-01-06   19.681499
# 2014-01-07   19.901501
# 2014-01-08   20.096001
# ...                ...
# 2024-06-24  185.570007
# 2024-06-25  186.339996
# 2024-06-26  193.610001
# 2024-06-27  197.850006
# 2024-06-28  193.250000
#
# [2640 rows x 1 columns]

# %% [markdown]
# ### calculation of the simple and log returns

# %%
# Daily percent change of the price

# %%
df["simple_rtn"] = df["Adj Close"].pct_change()

# %%
# The ratio indicates how much the price has changed from one day to the next.

# %%
df["log_rtn"] = np.log(df["Adj Close"] / df["Adj Close"].shift(1))

# %%
df
# Out:
#              Adj Close  simple_rtn   log_rtn
# Date
# 2014-01-02   19.898500         NaN       NaN
# 2014-01-03   19.822001   -0.003845 -0.003852
# 2014-01-06   19.681499   -0.007088 -0.007113
# 2014-01-07   19.901501    0.011178  0.011116
# 2014-01-08   20.096001    0.009773  0.009726
# ...                ...         ...       ...
# 2024-06-24  185.570007   -0.018564 -0.018738
# 2024-06-25  186.339996    0.004149  0.004141
# 2024-06-26  193.610001    0.039015  0.038273
# 2024-06-27  197.850006    0.021900  0.021663
# 2024-06-28  193.250000   -0.023250 -0.023525
#
# [2640 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Adj Close     0
# simple_rtn    1
# log_rtn       1
# dtype: int64

# %%
df["Adj Close"].plot();

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10), sharex=True)
df["Adj Close"].plot(ax=ax[0], kind = "line", title = "Amazon 2020-2024 daily - Adjusted Close");
df["simple_rtn"].plot(ax=ax[1], kind = "line", title = "Amazon 2020-2024 daily - Simple Returns");

# %%
import cufflinks as cf
import plotly.offline as iplot

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
qf = cf.QuantFig(raw_df, title="Amazon 2020-2024 daily", legend="top", name="Amazon price", kind='candlestick')
qf.add_volume()
qf.add_sma(periods=20, column="Close", color="red")
qf.add_ema(periods=20, color="green")

# %%
qf.iplot()
# Out:
# <div>                            <div id="ae532388-8add-427e-9df2-223725d11e28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ae532388-8add-427e-9df2-223725d11e28")) {                    Plotly.newPlot(                        "ae532388-8add-427e-9df2-223725d11e28",                        [{"marker":{"color":["#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#80808 ...

# %%
# 21 day rolling mean and std dev

# %%
df_rolling = df[["simple_rtn"]].rolling(window=21)\
                                .agg(["mean", "std"])
df_rolling.columns = df_rolling.columns.droplevel()

# %%
df_rolling.head(30)
# Out:
#                 mean       std
# Date
# 2014-01-02       NaN       NaN
# 2014-01-03       NaN       NaN
# 2014-01-06       NaN       NaN
# 2014-01-07       NaN       NaN
# 2014-01-08       NaN       NaN
# 2014-01-09       NaN       NaN
# 2014-01-10       NaN       NaN
# 2014-01-13       NaN       NaN
# 2014-01-14       NaN       NaN
# 2014-01-15       NaN       NaN
# 2014-01-16       NaN       NaN
# 2014-01-17       NaN       NaN
# 2014-01-21       NaN       NaN
# 2014-01-22       NaN       NaN
# 2014-01-23       NaN       NaN
# 2014-01-24       NaN       NaN
# 2014-01-27       NaN       NaN
# 2014-01-28       NaN       NaN
# 2014-01-29       NaN       NaN
# 2014-01-30       NaN       NaN
# 2014-01-31       NaN       NaN
# 2014-02-03 -0.006160  0.030446
# 2014-02-04 -0.005730  0.030545
# 2014-02-05 -0.005597  0.030544
# 2014-02-06 -0.005011  0.030998
# 2014-02-07 -0.004605  0.031256
# 2014-02-10 -0.004524  0.031264
# 2014-02-11 -0.004005  0.031288
# 2014-02-12 -0.004856  0.031890
# 2014-02-13 -0.004571  0.032119

# %%
df = df.join(df_rolling)

# %%
df
# Out:
#              Adj Close  simple_rtn   log_rtn      mean       std
# Date
# 2014-01-02   19.898500         NaN       NaN       NaN       NaN
# 2014-01-03   19.822001   -0.003845 -0.003852       NaN       NaN
# 2014-01-06   19.681499   -0.007088 -0.007113       NaN       NaN
# 2014-01-07   19.901501    0.011178  0.011116       NaN       NaN
# 2014-01-08   20.096001    0.009773  0.009726       NaN       NaN
# ...                ...         ...       ...       ...       ...
# 2024-06-24  185.570007   -0.018564 -0.018738  0.000698  0.011902
# 2024-06-25  186.339996    0.004149  0.004141  0.001436  0.011593
# 2024-06-26  193.610001    0.039015  0.038273  0.003373  0.014163
# 2024-06-27  197.850006    0.021900  0.021663  0.004047  0.014708
# 2024-06-28  193.250000   -0.023250 -0.023525  0.002974  0.015850
#
# [2640 rows x 5 columns]

# %%
# upper and lower tresholds

# %%
n_sigmas = 3
df["upper"] = df["mean"] + n_sigmas * df["std"]
df["lower"] = df["mean"] - n_sigmas * df["std"]

# %%
# outlier identification

# %%
df["outlier"] = (
    (df["simple_rtn"] > df["upper"]) | (df["simple_rtn"] < df["lower"])

)

# %%
df["outlier"].unique()
# Out:
# array([False,  True])

# %%
fig, ax = plt.subplots(figsize=(15, 10))

df[["simple_rtn", "upper", "lower"]].plot(ax=ax)
ax.scatter(df.loc[df["outlier"]].index,
           df.loc[df["outlier"], "simple_rtn"],
           color="black", label="outlier")
ax.set_title("Amazon returns including outlier based on tresholds bands")
ax.legend();

# %%
df[df["outlier"]==True]
# Out:
#              Adj Close  simple_rtn   log_rtn      mean       std     upper  \
# Date
# 2014-04-25   15.191500   -0.098828 -0.104060 -0.005375  0.029853  0.084185
# 2014-07-25   16.200500   -0.096484 -0.101461 -0.000113  0.028098  0.084180
# 2014-10-24   14.353000   -0.083403 -0.087087 -0.005207  0.021902  0.060500
# 2015-01-30   17.726500    0.137116  0.128495  0.006899  0.034542  0.110523
# 2015-04-24   22.254999    0.141311  0.132178  0.009188  0.032736  0.107397
# 2015-07-24   26.471001    0.097972  0.093465  0.009032  0.024536  0.082641
# 2015-08-24   23.168501   -0.062896 -0.064961 -0.006155  0.018639  0.049763
# 2016-04-29   32.979500    0.095664  0.091361  0.005303  0.024471  0.078717
# 2016-09-06   39.443501    0.021270  0.021047  0.001424  0.006589  0.021192
# 2016-09-09   38.007000   -0.030508 -0.030983 -0.000480  0.009649  0.028468
# 2016-10-28   38.816002   -0.051371 -0.052737 -0.003023  0.014473  0.040395
# 2017-10-27   55.047501    0.132164  0.124131  0.007115  0.029706  0.096234
# 2018-02-01   69.500000   -0.041967 -0.042873  0.007571  0.014847  0.052112
# 2018-06-25   83.157501   -0.030612 -0.031090  0.001805  0.010317  0.032756
# 2019-12-26   93.438499    0.044467  0.043506  0.002555  0.012140  0.038974
# 2020-01-31  100.435997    0.073791  0.071196  0.004158  0.019474  0.062580
# 2021-07-30  166.379501   -0.075649 -0.078663 -0.001338  0.022418  0.065917
# 2022-02-04  157.639496    0.135359  0.126949 -0.001186  0.041627  0.123695
# 2022-04-29  124.281502   -0.140494 -0.151398 -0.013015  0.038856  0.103553
# 2023-08-04  139.570007    0.082693  0.079452  0.004283  0.024861  0.078864
# 2024-02-02  171.809998    0.078666  0.075726  0.007195  0.021692  0.072271
#
#                lower  outlier
# Date
# 2014-04-25 -0.094935     True
# 2014-07-25 -0.084406     True
# 2014-10-24 -0.070915     True
# 2015-01-30 -0.096726     True
# 2015-04-24 -0.089021     True
# 2015-07-24 -0.064578     True
# 2015-08-24 -0.062073     True
# 2016-04-29 -0.068112     True
# 2016-09-06 -0.018344     True
# 2016-09-09 -0.029428     True
# 2016-10-28 -0.046441     True
# 2017-10-27 -0.082005     True
# 2018-02-01 -0.036970     True
# 2018-06-25 -0.029147     True
# 2019-12-26 -0.033865     True
# 2020-01-31 -0.054264     True
# 2021-07-30 -0.068593     True
# 2022-02-04 -0.126066     True
# 2022-04-29 -0.129583     True
# 2023-08-04 -0.070299     True
# 2024-02-02 -0.057881     True

# %%
# Stationary test using Dickey-Fuller test
adfuller(df["Adj Close"])
# Out:
# (-0.29180086139355604,
#  0.9266575749415258,
#  27,
#  2612,
#  {'1%': -3.4328560253199973,
#   '5%': -2.8626471695439784,
#   '10%': -2.567359385689561},
#  11412.561818503815)

# %%
df["Adj Close"].diff(1).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stat_test = df["Adj Close"].diff(1).dropna()

# %%
# Differencing stationary test

# %%
stat_test.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
adfuller(stat_test)
# Out:
# (-10.542113938725727,
#  8.596626843342673e-19,
#  26,
#  2612,
#  {'1%': -3.4328560253199973,
#   '5%': -2.8626471695439784,
#   '10%': -2.567359385689561},
#  11407.282392416662)

# %%
#####

# %%
# ***
acf(df["Adj Close"])
# Out:
# array([1.        , 0.99818223, 0.99633287, 0.99456482, 0.99295112,
#        0.99127688, 0.98957253, 0.98791806, 0.98631338, 0.9847689 ,
#        0.98319393, 0.98164202, 0.98005077, 0.978481  , 0.97684764,
#        0.97526896, 0.97372419, 0.97222211, 0.97074794, 0.96922511,
#        0.96774735, 0.96624015, 0.9647134 , 0.9632229 , 0.96171233,
#        0.96023927, 0.95882065, 0.95745057, 0.9559599 , 0.95444778,
#        0.95292065, 0.95141137, 0.94980158, 0.94821178, 0.94656373])

# %%
acf(stat_test)
# Out:
# array([ 1.00000000e+00, -2.12068997e-02, -1.64458865e-02, -3.42932486e-02,
#         4.50899960e-02, -1.24950991e-02, -7.59941277e-03, -5.79933683e-03,
#        -4.78453760e-02,  2.13472921e-02, -1.69463492e-02, -1.43357141e-03,
#        -1.52879340e-02,  3.99871314e-02, -1.28939809e-02, -3.18527585e-02,
#         3.93297048e-03,  5.83747316e-04,  3.55853983e-02, -7.54254634e-03,
#        -1.97856096e-02, -1.54495108e-02, -2.43993703e-02,  2.34439094e-02,
#        -2.48580961e-02, -5.14098801e-02, -3.17900989e-02,  7.21286643e-02,
#        -9.57809039e-04,  2.00680043e-02, -3.25398162e-02,  5.21428612e-02,
#        -1.10099419e-02,  2.86696211e-02, -3.58237108e-02])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(stat_test);

# %%
lag_plot(df["Adj Close"]);

# %%
# Seasonality detection using autocorrelation - no seasonality found
plot_acf(stat_test, lags=40);

# %%
# Partial auto correlation function identifies AR to estimate number of lags.
plot_pacf(stat_test, method='ywm', lags=40);

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df.index = pd.to_datetime(df.index)

# %%
seasonal = seasonal_decompose(df["Adj Close"], period=365, model="multiplicative ").plot();

# %%
plt.figure(figsize=(22,8));
seasonal_decompose(df["Adj Close"], period=365, model="multiplicative ").seasonal.plot().set_ylabel("Seasonal");

# %%
plt.figure(figsize=(20,8))
seasonal_decompose(df["Adj Close"], period=365, model="multiplicative ").resid.plot().set_ylabel("Residuals");

# %%
# Tripple exponential smooting - Holt-Winters method supporting  both -  trends and seasonality in the data.
# Exponential Smoothing is a widely used technique for forecasting time series data.

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
# multiplicative Tripple exponential smooting
df["TESmul12"] = ExponentialSmoothing(df["Adj Close"],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues
df.head()
# Out:
#             Adj Close  simple_rtn   log_rtn  mean  std  upper  lower  outlier  \
# Date
# 2014-01-02  19.898500         NaN       NaN   NaN  NaN    NaN    NaN    False
# 2014-01-03  19.822001   -0.003845 -0.003852   NaN  NaN    NaN    NaN    False
# 2014-01-06  19.681499   -0.007088 -0.007113   NaN  NaN    NaN    NaN    False
# 2014-01-07  19.901501    0.011178  0.011116   NaN  NaN    NaN    NaN    False
# 2014-01-08  20.096001    0.009773  0.009726   NaN  NaN    NaN    NaN    False
#
#              TESmul12
# Date
# 2014-01-02  19.918421
# 2014-01-03  19.896600
# 2014-01-06  19.800966
# 2014-01-07  19.718589
# 2014-01-08  19.866510

# %%
df.tail()
# Out:
#              Adj Close  simple_rtn   log_rtn      mean       std     upper  \
# Date
# 2024-06-24  185.570007   -0.018564 -0.018738  0.000698  0.011902  0.036403
# 2024-06-25  186.339996    0.004149  0.004141  0.001436  0.011593  0.036216
# 2024-06-26  193.610001    0.039015  0.038273  0.003373  0.014163  0.045862
# 2024-06-27  197.850006    0.021900  0.021663  0.004047  0.014708  0.048171
# 2024-06-28  193.250000   -0.023250 -0.023525  0.002974  0.015850  0.050525
#
#                lower  outlier    TESmul12
# Date
# 2024-06-24 -0.035007    False  189.352818
# 2024-06-25 -0.033343    False  185.835187
# 2024-06-26 -0.039116    False  186.221850
# 2024-06-27 -0.040076    False  193.551248
# 2024-06-28 -0.044577    False  197.199116

# %%
# exponential weighted moving average

# %%
span = 12
alpha = 2/(span+1)

df["EWMA12"] = df["Adj Close"].ewm(alpha=alpha,adjust=False).mean()

# %%
df[["Adj Close","TESmul12","EWMA12" ]].tail(204).plot(figsize=(12,10));

# %%
# train-test 80/20 split

# %%
split = int(df.shape[0]*.2)

# %%
df_train = df[:-split]
df_test = df[-split:]

# %%
df_test.shape
# Out:
# (528, 10)

# %%
start = len(df_train)
end = start + len(df_test) - 1

# %%
test_model_ExpSm = ExponentialSmoothing(df_train["Adj Close"],trend='add',seasonal='mul',seasonal_periods=365).fit()

# %%
predictions = test_model_ExpSm.forecast(528)

# %%
# model is pretty bad, negative value suggest that the Exponential Smoothing model with multiplicative trend and seasonal components might not be suitable that data.
# the predictions are  significantly worse than a simple mean

# interesting to see that additive trend and multiplicative seasonal comp. has smaller error than mul/ul or add/add or mul/add with seasonal period 365

r2_score(predictions, df_test["Adj Close"])
# Out:
# -6.765015081989945

# %%
# mean square error suggests that between predictions and actual values, the difference is around 26.61
mean_squared_error(predictions, df_test["Adj Close"])**0.5
# Out:
# 26.609005231618447

# %%
# full data model fit, just to obtail 12 days graphical forecast overview (just to see with real data in the future ONLY!!)

# %%
model_ExpSm = ExponentialSmoothing(df["Adj Close"],trend='add',seasonal='mul',seasonal_periods=365).fit()

# %%
pred_ES = model_ExpSm.forecast(12)

# %%
pred_ES
# Out:
# 2640    190.367101
# 2641    191.045988
# 2642    190.124571
# 2643    190.260871
# 2644    189.478971
# 2645    188.407436
# 2646    188.923730
# 2647    190.389038
# 2648    191.466307
# 2649    188.442300
# 2650    187.112927
# 2651    189.507186
# dtype: float64

# %%
# Exponental Smoothing prediction 12 months (last 204 periods). 
# Interesting is that the prediction despite negative r2 looks reasonable (based on technical analysis only)

df["Adj Close"].reset_index(drop=True).tail(204).plot(figsize=(12,10));
pred_ES.plot(figsize=(12,10));
